# %% [markdown]
# # Normalizzazione
#
# La normalizzazione è una tecnica di pre-elaborazione dei dati usata per ridimensionare le funzionalità nello stesso intervallo, in genere compreso tra 0 e 1, in modo che possano essere elaborate in modo più accurato da un algoritmo di Machine Learning

# %% [markdown]
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/python/normalization.png " width="1200">

# %%
import pandas as pd
df = pd.DataFrame({
               'A':[1,2,3],
               'B':[100,300,500],
               'C':list('abc')
                })
df
# Out:
#    A    B  C
# 0  1  100  a
# 1  2  300  b
# 2  3  500  c

# %%
#nella normalizzazione andiamo a sottrarre ad ogni valore il minimo della colonna, diviso il delta (max-min)

def normalize(df):
    result = df.copy()
    for feature_name in df.columns:
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        result[feature_name] = (df[feature_name] - min_value) / (max_value - min_value)
    return result

# %%
normalize(df[['A','B']])
# Out:
#      A    B
# 0  0.0  0.0
# 1  0.5  0.5
# 2  1.0  1.0

# %%
df.describe().T
# Out:
#    count   mean    std    min    25%    50%    75%    max
# A    3.0    2.0    1.0    1.0    1.5    2.0    2.5    3.0
# B    3.0  300.0  200.0  100.0  200.0  300.0  400.0  500.0

# %% [markdown]
# ### MinMaxScaler

# %%
import pandas as pd
df = pd.DataFrame({
               'A':[1,2,3],
               'B':[100,300,500],
             })
df
# Out:
#    A    B
# 0  1  100
# 1  2  300
# 2  3  500

# %%
# Using sklearn
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
arr_scaled = scaler.fit_transform(df)

print(arr_scaled)

df_scaled = pd.DataFrame(arr_scaled, columns=df.columns,index=df.index)
df_scaled
# Out:
# [[0.  0. ]
#  [0.5 0.5]
#  [1.  1. ]]
#      A    B
# 0  0.0  0.0
# 1  0.5  0.5
# 2  1.0  1.0

# %%
df_scaled.describe().T
# Out:
#    count  mean  std  min   25%  50%   75%  max
# A    3.0   0.5  0.5  0.0  0.25  0.5  0.75  1.0
# B    3.0   0.5  0.5  0.0  0.25  0.5  0.75  1.0

# %% [markdown]
# ## Standardizzazione Manuale
#
# La standardizzazione è un altro metodo di scalatura in cui i valori vengono centrati intorno alla media con una deviazione standard unitaria. Ciò significa che la media dell'attributo diventa zero e la distribuzione risultante ha una deviazione standard unitaria

# %%
df = pd.DataFrame({
               'A':[1,2,3],
               'B':[100,300,500],
               'C':list('abc')
             })
df
# Out:
#    A    B  C
# 0  1  100  a
# 1  2  300  b
# 2  3  500  c

# %%
## Column A --> Mean=0 std=1
df.iloc[:,0:-1] = df.iloc[:,0:-1].apply(lambda x: (x-x.mean())/ x.std(), axis=0)
df
# Out:
# <ipython-input-10-f108c0b8651d>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0   -1.0
# 1    0.0
# 2    1.0
# Name: A, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,0:-1] = df.iloc[:,0:-1].apply(lambda x: (x-x.mean())/ x.std(), axis=0)
# <ipython-input-10-f108c0b8651d>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0   -1.0
# 1    0.0
# 2    1.0
# Name: B, dtype: float64' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,0:-1] = df.iloc[:,0:-1].apply(lambda x: (x-x.mean())/ x.std(), axis=0)
#      A    B  C
# 0 -1.0 -1.0  a
# 1  0.0  0.0  b
# 2  1.0  1.0  c

# %%
df.describe().T
# Out:
#    count  mean  std  min  25%  50%  75%  max
# A    3.0   0.0  1.0 -1.0 -0.5  0.0  0.5  1.0
# B    3.0   0.0  1.0 -1.0 -0.5  0.0  0.5  1.0

# %% [markdown]
# ## Standardizzazione con Sklearn

# %%
import pandas as pd

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df = pd.DataFrame({
               'A':[1,2,3],
               'B':[100,300,500],
               'C':list('abc')
             })
df.iloc[:,0:-1] = scaler.fit_transform(df.iloc[:,0:-1])
df
# Out:
# <ipython-input-13-c52005729571>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.22474487  0.          1.22474487]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,0:-1] = scaler.fit_transform(df.iloc[:,0:-1])
# <ipython-input-13-c52005729571>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.22474487  0.          1.22474487]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.iloc[:,0:-1] = scaler.fit_transform(df.iloc[:,0:-1])
#           A         B  C
# 0 -1.224745 -1.224745  a
# 1  0.000000  0.000000  b
# 2  1.224745  1.224745  c

# %%
df.describe().T
# Out:
#    count  mean       std       min       25%  50%       75%       max
# A    3.0   0.0  1.224745 -1.224745 -0.612372  0.0  0.612372  1.224745
# B    3.0   0.0  1.224745 -1.224745 -0.612372  0.0  0.612372  1.224745

# %%
pd.DataFrame(scaler.inverse_transform(df.iloc[:,0:-1] ), columns = ['A','B'])
# Out:
#      A      B
# 0  1.0  100.0
# 1  2.0  300.0
# 2  3.0  500.0
